# %% [markdown]
# # <div style="text-align: center"> Social segregation algorithme </div>
#
# <div style="text-align: right; font-size: 16px; font-style: italic"> Author: Corentin Pradier </div>

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import matplotlib.ticker as ticker
from itertools import product
import random
from tqdm import tqdm

import sys

sys.path.append("/Users/corentinpradier/Documents/Codes")

from Cocopy.Segregation import Segregation

# %%
segregation = Segregation(vaccum=100)
segregation.one_step(t=3000)
segregation.plot(colors=["darkorange", "white", "darkblue"], titles=None)
# Out:
# Segregation in progress: 100%|██████████| 3000/3000 [00:01<00:00, 2516.20it/s]

# %%
segregation = Segregation(vaccum=50)
segregation.one_step(t=5000)
segregation.plot()
# Out:
# Segregation in progress: 100%|██████████| 5000/5000 [00:01<00:00, 2641.97it/s]

# %%
segregation = Segregation(vaccum=1)
segregation.one_step()
segregation.plot()
# Out:
# Segregation in progress: 100%|██████████| 10000/10000 [00:03<00:00, 2687.64it/s]
